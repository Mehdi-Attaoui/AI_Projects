# %% [markdown]
# # TP 3 : Détection de sentiments avec un RNN - Mehdi ATTAOUI

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## 1. Données d’apprentissage :

# %%
phrases = [
    "Je suis très content",
    "C'était une belle journée",
    "Je suis déçu",
    "C'était horrible",
    "J'adore ce film",
    "Je déteste ce livre"
]

sentiment = [1, 1, 0, 0, 1, 0]  
# Step 2: Create the DataFrame
data = pd.DataFrame({
    'Phrase': phrases,
    'Sentiment': sentiment
})

# %%
data
# Out:
#                       Phrase  Sentiment
# 0       Je suis très content          1
# 1  C'était une belle journée          1
# 2               Je suis déçu          0
# 3           C'était horrible          0
# 4            J'adore ce film          1
# 5        Je déteste ce livre          0

# %% [markdown]
# ## 2. Prétraitement

# %% [markdown]
# ### importation de NLTK

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\mehdi\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# ### tokenization avec expressions regulier pour gerer les ponctuations du langue francais

# %%
from nltk.tokenize import RegexpTokenizer

tokenizer = RegexpTokenizer(r"\w+")

data['Tokens'] = data['Phrase'].apply(lambda x: tokenizer.tokenize(x.lower()))

data
# Out:
#                       Phrase  Sentiment                           Tokens
# 0       Je suis très content          1        [je, suis, très, content]
# 1  C'était une belle journée          1  [c, était, une, belle, journée]
# 2               Je suis déçu          0                 [je, suis, déçu]
# 3           C'était horrible          0             [c, était, horrible]
# 4            J'adore ce film          1             [j, adore, ce, film]
# 5        Je déteste ce livre          0         [je, déteste, ce, livre]

# %% [markdown]
# ### creation du vocabulaire, et convertir en sequence des indices

# %%
tokens = data['Tokens'].explode()
vocab_list = sorted(list(set(tokens)))
word_to_index = {"<PAD>": 0}
word_to_index.update({word: idx + 1 for idx, word in enumerate(vocab_list)})

# Conversion en indices
data['Token_Indices'] = data['Tokens'].apply(lambda tokens: [word_to_index[word] for word in tokens])

# %%
data
# Out:
#                       Phrase  ...       Token_Indices
# 0       Je suis très content  ...     [11, 14, 15, 5]
# 1  C'était une belle journée  ...  [3, 17, 16, 2, 12]
# 2               Je suis déçu  ...         [11, 14, 7]
# 3           C'était horrible  ...          [3, 17, 9]
# 4            J'adore ce film  ...       [10, 1, 4, 8]
# 5        Je déteste ce livre  ...      [11, 6, 4, 13]
#
# [6 rows x 4 columns]

# %% [markdown]
# ### ajoutons une jeton pad = 0

# %%
def pad_sequences_numpy(sequences, max_len=None, pad_value=0):
    if max_len is None:
        max_len = max(len(seq) for seq in sequences)
    padded = np.full((len(sequences), max_len), pad_value)
    for i, seq in enumerate(sequences):
        padded[i, :len(seq)] = seq
    return padded

padded_np = pad_sequences_numpy(data['Token_Indices'].tolist(), pad_value=word_to_index["<PAD>"])
data['Padded_Indices'] = list(padded_np)

data
# Out:
#                       Phrase  Sentiment  ...       Token_Indices      Padded_Indices
# 0       Je suis très content          1  ...     [11, 14, 15, 5]  [11, 14, 15, 5, 0]
# 1  C'était une belle journée          1  ...  [3, 17, 16, 2, 12]  [3, 17, 16, 2, 12]
# 2               Je suis déçu          0  ...         [11, 14, 7]   [11, 14, 7, 0, 0]
# 3           C'était horrible          0  ...          [3, 17, 9]    [3, 17, 9, 0, 0]
# 4            J'adore ce film          1  ...       [10, 1, 4, 8]    [10, 1, 4, 8, 0]
# 5        Je déteste ce livre          0  ...      [11, 6, 4, 13]   [11, 6, 4, 13, 0]
#
# [6 rows x 5 columns]

# %% [markdown]
# ## creation RNN simple

# %%
import torch
import torch.nn as nn

class SimpleRNNClassifier(nn.Module):
    def __init__(self, vocab_size, embedding_dim, hidden_dim, rnn_type="GRU"):
        super(SimpleRNNClassifier, self).__init__()
        
        self.embedding = nn.Embedding(num_embeddings=vocab_size, embedding_dim=embedding_dim, padding_idx=0)
        
        if rnn_type == "LSTM":
            self.rnn = nn.LSTM(input_size=embedding_dim, hidden_size=hidden_dim, batch_first=True)
        else:
            self.rnn = nn.GRU(input_size=embedding_dim, hidden_size=hidden_dim, batch_first=True)
        
        self.fc = nn.Linear(hidden_dim, 1)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        embedded = self.embedding(x)  
        output, hidden = self.rnn(embedded) 
        
        if isinstance(hidden, tuple): 
            hidden = hidden[0]

        hidden = hidden.squeeze(0)  
        out = self.fc(hidden)       
        out = self.sigmoid(out)     
        return out

# %%
from torch.utils.data import DataLoader, TensorDataset

# Convertir les données en tenseurs PyTorch
X = torch.tensor(data["Padded_Indices"], dtype=torch.long)
y = torch.tensor(data['Sentiment'].values, dtype=torch.float32).unsqueeze(1)  

# Créer DataLoader
dataset = TensorDataset(X, y)
loader = DataLoader(dataset, batch_size=2, shuffle=True)

# %% [markdown]
# ### Fonction Cout

# %%
criterion = nn.BCELoss()

# %%
import torch.optim as optim
import matplotlib.pyplot as plt

# Recréons le modèle (au cas où)
model = SimpleRNNClassifier(vocab_size=len(word_to_index), embedding_dim=16, hidden_dim=32, rnn_type="LSTM")

# Optimiseur
optimizer = optim.Adam(model.parameters(), lr=0.01)

# Pour stocker les pertes
losses = []

# Entraînement
num_epochs = 200
model.train()

for epoch in range(num_epochs):
    total_loss = 0
    for batch_X, batch_y in loader:
        optimizer.zero_grad()
        outputs = model(batch_X)               # prédictions
        loss = criterion(outputs, batch_y)     # calcul de la perte
        loss.backward()                        # rétropropagation
        optimizer.step()                       # mise à jour des poids
        total_loss += loss.item()

    avg_loss = total_loss / len(loader)
    losses.append(avg_loss)
    print(f"Époque {epoch+1}/{num_epochs} - Perte moyenne : {avg_loss:.4f}")
# Out:
# Époque 1/200 - Perte moyenne : 0.7149
# Époque 2/200 - Perte moyenne : 0.6776
# Époque 3/200 - Perte moyenne : 0.6531
# Époque 4/200 - Perte moyenne : 0.6247
# Époque 5/200 - Perte moyenne : 0.5661
# Époque 6/200 - Perte moyenne : 0.4978
# Époque 7/200 - Perte moyenne : 0.3835
# Époque 8/200 - Perte moyenne : 0.2458
# Époque 9/200 - Perte moyenne : 0.1203
# Époque 10/200 - Perte moyenne : 0.0614
# Époque 11/200 - Perte moyenne : 0.0257
# Époque 12/200 - Perte moyenne : 0.0126
# Époque 13/200 - Perte moyenne : 0.0063
# Époque 14/200 - Perte moyenne : 0.0036
# Époque 15/200 - Perte moyenne : 0.0023
# Époque 16/200 - Perte moyenne : 0.0017
# Époque 17/200 - Perte moyenne : 0.0014
# Époque 18/200 - Perte moyenne : 0.0011
# Époque 19/200 - Perte moyenne : 0.0010
# Époque 20/200 - Perte moyenne : 0.0009
# Époque 21/200 - Perte moyenne : 0.0008
# Époque 22/200 - Perte moyenne : 0.0007
# Époque 23/200 - Perte moyenne : 0.0007
# Époque 24/200 - Perte moyenne : 0.0006
# Époque 25/200 - Perte moyenne : 0.0006
# Époque 26/200 - Perte moyenne : 0.0006
# Époque 27/200 - Perte moyenne : 0.0005
# Époque 28/200 - Perte moyenne : 0.0005
# Époque 29/200 - Perte moyenne : 0.0005
# Époque 30/200 - Perte moyenne : 0.0005
# Époque 31/200 - Perte moyenne : 0.0005
# Époque 32/200 - Perte moyenne : 0.0005
# Époque 33/200 - Perte moyenne : 0.0004
# Époque 34/200 - Perte moyenne : 0.0004
# Époque 35/200 - Perte moyenne : 0.0004
# Époque 36/200 - Perte moyenne : 0.0004
# Époque 37/200 - Perte moyenne : 0.0004
# Époque 38/200 - Perte moyenne : 0.0004
# Époque 39/200 - Perte moyenne : 0.0004
# Époque 40/200 - Perte moyenne : 0.0004
# Époque 41/200 - Perte moyenne : 0.0004
# Époque 42/200 - Perte moyenne : 0.0003
# Époque 43/200 - Perte moyenne : 0.0003
# Époque 44/200 - Perte moyenne : 0.0003
# Époque 45/200 - Perte moyenne : 0.0003
# Époque 46/200 - Perte moyenne : 0.0003
# Époque 47/200 - Perte moyenne : 0.0003
# Époque 48/200 - Perte moyenne : 0.0003
# Époque 49/200 - Perte moyenne : 0.0003
# Époque 50/200 - Perte moyenne : 0.0003
# Époque 51/200 - Perte moyenne : 0.0003
# Époque 52/200 - Perte moyenne : 0.0003
# Époque 53/200 - Perte moyenne : 0.0003
# Époque 54/200 - Perte moyenne : 0.0003
# Époque 55/200 - Perte moyenne : 0.0003
# Époque 56/200 - Perte moyenne : 0.0003
# Époque 57/200 - Perte moyenne : 0.0003
# Époque 58/200 - Perte moyenne : 0.0003
# Époque 59/200 - Perte moyenne : 0.0002
# Époque 60/200 - Perte moyenne : 0.0002
# Époque 61/200 - Perte moyenne : 0.0002
# Époque 62/200 - Perte moyenne : 0.0002
# Époque 63/200 - Perte moyenne : 0.0002
# Époque 64/200 - Perte moyenne : 0.0002
# Époque 65/200 - Perte moyenne : 0.0002
# Époque 66/200 - Perte moyenne : 0.0002
# Époque 67/200 - Perte moyenne : 0.0002
# Époque 68/200 - Perte moyenne : 0.0002
# Époque 69/200 - Perte moyenne : 0.0002
# Époque 70/200 - Perte moyenne : 0.0002
# Époque 71/200 - Perte moyenne : 0.0002
# Époque 72/200 - Perte moyenne : 0.0002
# Époque 73/200 - Perte moyenne : 0.0002
# Époque 74/200 - Perte moyenne : 0.0002
# Époque 75/200 - Perte moyenne : 0.0002
# Époque 76/200 - Perte moyenne : 0.0002
# Époque 77/200 - Perte moyenne : 0.0002
# Époque 78/200 - Perte moyenne : 0.0002
# Époque 79/200 - Perte moyenne : 0.0002
# Époque 80/200 - Perte moyenne : 0.0002
# Époque 81/200 - Perte moyenne : 0.0002
# Époque 82/200 - Perte moyenne : 0.0002
# Époque 83/200 - Perte moyenne : 0.0002
# Époque 84/200 - Perte moyenne : 0.0002
# Époque 85/200 - Perte moyenne : 0.0002
# Époque 86/200 - Perte moyenne : 0.0002
# Époque 87/200 - Perte moyenne : 0.0002
# Époque 88/200 - Perte moyenne : 0.0002
# Époque 89/200 - Perte moyenne : 0.0002
# Époque 90/200 - Perte moyenne : 0.0001
# Époque 91/200 - Perte moyenne : 0.0001
# Époque 92/200 - Perte moyenne : 0.0001
# Époque 93/200 - Perte moyenne : 0.0001
# Époque 94/200 - Perte moyenne : 0.0001
# Époque 95/200 - Perte moyenne : 0.0001
# Époque 96/200 - Perte moyenne : 0.0001
# Époque 97/200 - Perte moyenne : 0.0001
# Époque 98/200 - Perte moyenne : 0.0001
# Époque 99/200 - Perte moyenne : 0.0001
# Époque 100/200 - Perte moyenne : 0.0001
# Époque 101/200 - Perte moyenne : 0.0001
# Époque 102/200 - Perte moyenne : 0.0001
# Époque 103/200 - Perte moyenne : 0.0001
# Époque 104/200 - Perte moyenne : 0.0001
# Époque 105/200 - Perte moyenne : 0.0001
# Époque 106/200 - Perte moyenne : 0.0001
# Époque 107/200 - Perte moyenne : 0.0001
# Époque 108/200 - Perte moyenne : 0.0001
# Époque 109/200 - Perte moyenne : 0.0001
# Époque 110/200 - Perte moyenne : 0.0001
# Époque 111/200 - Perte moyenne : 0.0001
# Époque 112/200 - Perte moyenne : 0.0001
# Époque 113/200 - Perte moyenne : 0.0001
# Époque 114/200 - Perte moyenne : 0.0001
# Époque 115/200 - Perte moyenne : 0.0001
# Époque 116/200 - Perte moyenne : 0.0001
# Époque 117/200 - Perte moyenne : 0.0001
# Époque 118/200 - Perte moyenne : 0.0001
# Époque 119/200 - Perte moyenne : 0.0001
# Époque 120/200 - Perte moyenne : 0.0001
# Époque 121/200 - Perte moyenne : 0.0001
# Époque 122/200 - Perte moyenne : 0.0001
# Époque 123/200 - Perte moyenne : 0.0001
# Époque 124/200 - Perte moyenne : 0.0001
# Époque 125/200 - Perte moyenne : 0.0001
# Époque 126/200 - Perte moyenne : 0.0001
# Époque 127/200 - Perte moyenne : 0.0001
# Époque 128/200 - Perte moyenne : 0.0001
# Époque 129/200 - Perte moyenne : 0.0001
# Époque 130/200 - Perte moyenne : 0.0001
# Époque 131/200 - Perte moyenne : 0.0001
# Époque 132/200 - Perte moyenne : 0.0001
# Époque 133/200 - Perte moyenne : 0.0001
# Époque 134/200 - Perte moyenne : 0.0001
# Époque 135/200 - Perte moyenne : 0.0001
# Époque 136/200 - Perte moyenne : 0.0001
# Époque 137/200 - Perte moyenne : 0.0001
# Époque 138/200 - Perte moyenne : 0.0001
# Époque 139/200 - Perte moyenne : 0.0001
# Époque 140/200 - Perte moyenne : 0.0001
# Époque 141/200 - Perte moyenne : 0.0001
# Époque 142/200 - Perte moyenne : 0.0001
# Époque 143/200 - Perte moyenne : 0.0001
# Époque 144/200 - Perte moyenne : 0.0001
# Époque 145/200 - Perte moyenne : 0.0001
# Époque 146/200 - Perte moyenne : 0.0001
# Époque 147/200 - Perte moyenne : 0.0001
# Époque 148/200 - Perte moyenne : 0.0001
# Époque 149/200 - Perte moyenne : 0.0001
# Époque 150/200 - Perte moyenne : 0.0001
# Époque 151/200 - Perte moyenne : 0.0001
# Époque 152/200 - Perte moyenne : 0.0001
# Époque 153/200 - Perte moyenne : 0.0001
# Époque 154/200 - Perte moyenne : 0.0001
# Époque 155/200 - Perte moyenne : 0.0001
# Époque 156/200 - Perte moyenne : 0.0001
# Époque 157/200 - Perte moyenne : 0.0001
# Époque 158/200 - Perte moyenne : 0.0001
# Époque 159/200 - Perte moyenne : 0.0001
# Époque 160/200 - Perte moyenne : 0.0001
# Époque 161/200 - Perte moyenne : 0.0001
# Époque 162/200 - Perte moyenne : 0.0001
# Époque 163/200 - Perte moyenne : 0.0001
# Époque 164/200 - Perte moyenne : 0.0001
# Époque 165/200 - Perte moyenne : 0.0001
# Époque 166/200 - Perte moyenne : 0.0001
# Époque 167/200 - Perte moyenne : 0.0001
# Époque 168/200 - Perte moyenne : 0.0001
# Époque 169/200 - Perte moyenne : 0.0001
# Époque 170/200 - Perte moyenne : 0.0001
# Époque 171/200 - Perte moyenne : 0.0001
# Époque 172/200 - Perte moyenne : 0.0001
# Époque 173/200 - Perte moyenne : 0.0001
# Époque 174/200 - Perte moyenne : 0.0001
# Époque 175/200 - Perte moyenne : 0.0001
# Époque 176/200 - Perte moyenne : 0.0001
# Époque 177/200 - Perte moyenne : 0.0001
# Époque 178/200 - Perte moyenne : 0.0001
# Époque 179/200 - Perte moyenne : 0.0001
# Époque 180/200 - Perte moyenne : 0.0001
# Époque 181/200 - Perte moyenne : 0.0001
# Époque 182/200 - Perte moyenne : 0.0001
# Époque 183/200 - Perte moyenne : 0.0001
# Époque 184/200 - Perte moyenne : 0.0001
# Époque 185/200 - Perte moyenne : 0.0001
# Époque 186/200 - Perte moyenne : 0.0001
# Époque 187/200 - Perte moyenne : 0.0001
# Époque 188/200 - Perte moyenne : 0.0001
# Époque 189/200 - Perte moyenne : 0.0001
# Époque 190/200 - Perte moyenne : 0.0001
# Époque 191/200 - Perte moyenne : 0.0001
# Époque 192/200 - Perte moyenne : 0.0001
# Époque 193/200 - Perte moyenne : 0.0001
# Époque 194/200 - Perte moyenne : 0.0001
# Époque 195/200 - Perte moyenne : 0.0001
# Époque 196/200 - Perte moyenne : 0.0001
# Époque 197/200 - Perte moyenne : 0.0001
# Époque 198/200 - Perte moyenne : 0.0001
# Époque 199/200 - Perte moyenne : 0.0001
# Époque 200/200 - Perte moyenne : 0.0001

# %% [markdown]
# ### Fonction predection

# %%
def predict_sentiment(phrase, model, tokenizer, word_to_index, max_len=None):
    model.eval()
    with torch.no_grad():
       
        tokens = tokenizer.tokenize(phrase.lower())
        
    
        indices = [word_to_index.get(word, 0) for word in tokens]
        
      
        if max_len is None:
            max_len = X.shape[1]
        padded = indices + [0]*(max_len - len(indices))
        padded = padded[:max_len]  
        # 4. Convertir en tenseur
        input_tensor = torch.tensor([padded], dtype=torch.long) 
        # 5. Prédiction
        output = model(input_tensor)
        prob = output.item()

        # 6. Interprétation
        label = 1 if prob >= 0.5 else 0
        return prob, label

# %%
phrase1 = "je suis heureux"
phrase2 = "je suis triste"

prob1, label1 = predict_sentiment(phrase1, model, tokenizer, word_to_index)
prob2, label2 = predict_sentiment(phrase2, model, tokenizer, word_to_index)

print(f"Phrase: '{phrase1}' → Sentiment prédit: {label1} (proba={prob1:.4f})")
print(f"Phrase: '{phrase2}' → Sentiment prédit: {label2} (proba={prob2:.4f})")
# Out:
# Phrase: 'je suis heureux' → Sentiment prédit: 0 (proba=0.0097)
# Phrase: 'je suis triste' → Sentiment prédit: 0 (proba=0.0097)

# %% [markdown]
# ### ajouter heureux et triste pour que notre model peut l'apprendre

# %%
new_phrases = [
    "Je suis heureux",     
    "Je suis triste"       
]
new_sentiments = [1, 0]


new_data = pd.DataFrame({
    'Phrase': new_phrases,
    'Sentiment': new_sentiments
})
data_extended = pd.concat([data[['Phrase', 'Sentiment']], new_data], ignore_index=True)


data_extended['Tokens'] = data_extended['Phrase'].apply(lambda x: tokenizer.tokenize(x.lower()))


tokens = data_extended['Tokens'].explode()
vocab_list = sorted(list(set(tokens)))
word_to_index = {"<PAD>": 0}
word_to_index.update({word: idx + 1 for idx, word in enumerate(vocab_list)})

data_extended['Token_Indices'] = data_extended['Tokens'].apply(lambda tokens: [word_to_index[word] for word in tokens])

padded_np = pad_sequences_numpy(data_extended['Token_Indices'].tolist(), pad_value=word_to_index["<PAD>"])
data_extended['Padded_Indices'] = list(padded_np)

X_ext = torch.tensor(data_extended['Padded_Indices'].tolist(), dtype=torch.long)
y_ext = torch.tensor(data_extended['Sentiment'].values, dtype=torch.float32).unsqueeze(1)

# 🔹 DataLoaer
dataset_ext = TensorDataset(X_ext, y_ext)
loader_ext = DataLoader(dataset_ext, batch_size=2, shuffle=True)

# %%
from torch.utils.data import DataLoader, TensorDataset

X = torch.tensor(data["Padded_Indices"], dtype=torch.long)
y = torch.tensor(data['Sentiment'].values, dtype=torch.float32).unsqueeze(1)


dataset = TensorDataset(X, y)
loader = DataLoader(dataset, batch_size=2, shuffle=True)

# %%
model = SimpleRNNClassifier(vocab_size=len(word_to_index), embedding_dim=16, hidden_dim=32, rnn_type="LSTM")
optimizer = optim.Adam(model.parameters(), lr=0.01)
criterion = nn.BCELoss()


losses = []
num_epochs = 200
model.train()

for epoch in range(num_epochs):
    total_loss = 0
    for batch_X, batch_y in loader_ext:
        optimizer.zero_grad()
        outputs = model(batch_X)
        loss = criterion(outputs, batch_y)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
    avg_loss = total_loss / len(loader_ext)
    losses.append(avg_loss)
    if epoch % 20 == 0:
        print(f"Epoch {epoch+1}/{num_epochs} - Loss: {avg_loss:.4f}")
# Out:
# Epoch 1/200 - Loss: 0.6984
# Epoch 21/200 - Loss: 0.0004
# Epoch 41/200 - Loss: 0.0002
# Epoch 61/200 - Loss: 0.0001
# Epoch 81/200 - Loss: 0.0001
# Epoch 101/200 - Loss: 0.0001
# Epoch 121/200 - Loss: 0.0001
# Epoch 141/200 - Loss: 0.0000
# Epoch 161/200 - Loss: 0.0000
# Epoch 181/200 - Loss: 0.0000

# %%
model = SimpleRNNClassifier(vocab_size=len(word_to_index), embedding_dim=16, hidden_dim=32, rnn_type="LSTM")
optimizer = optim.Adam(model.parameters(), lr=0.01)
criterion = nn.BCELoss()

losses = []
num_epochs = 200
model.train()

for epoch in range(num_epochs):
    total_loss = 0
    for batch_X, batch_y in loader_ext:
        optimizer.zero_grad()
        outputs = model(batch_X)
        loss = criterion(outputs, batch_y)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
    avg_loss = total_loss / len(loader_ext)
    losses.append(avg_loss)
    if epoch % 20 == 0:
        print(f"Epoch {epoch+1}/{num_epochs} - Loss: {avg_loss:.4f}")
# Out:
# Epoch 1/200 - Loss: 0.7067
# Epoch 21/200 - Loss: 0.0005
# Epoch 41/200 - Loss: 0.0003
# Epoch 61/200 - Loss: 0.0002
# Epoch 81/200 - Loss: 0.0001
# Epoch 101/200 - Loss: 0.0001
# Epoch 121/200 - Loss: 0.0001
# Epoch 141/200 - Loss: 0.0001
# Epoch 161/200 - Loss: 0.0000
# Epoch 181/200 - Loss: 0.0000

# %% [markdown]
# ### on remarque que le model peut detecter heureux et triste

# %%
phrase1 = "je suis heureux"
phrase2 = "je suis triste"

prob1, label1 = predict_sentiment(phrase1, model, tokenizer, word_to_index)
prob2, label2 = predict_sentiment(phrase2, model, tokenizer, word_to_index)

print(f"Phrase: '{phrase1}' → Sentiment prédit: {label1} (proba={prob1:.4f})")
print(f"Phrase: '{phrase2}' → Sentiment prédit: {label2} (proba={prob2:.4f})")
# Out:
# Phrase: 'je suis heureux' → Sentiment prédit: 1 (proba=1.0000)
# Phrase: 'je suis triste' → Sentiment prédit: 0 (proba=0.0000)

# %% [markdown]
# # pourquoi ajoutons jetons <pad>?

# %% [markdown]
# #### Parce que les phrases n’ont pas toutes la même longueur, mais le modèle a besoin que tout soit de la même taille pour apprendre correctement. Alors on ajoute des <PAD> pour compléter les phrases courtes

# %% [markdown]
# # 1 Pourquoi un RNN est utile ici ?

# %% [markdown]
# #### Parce qu’un RNN gere bien les sequences, on sait bien que le text est tous lie entre eux , les mots ne sont pas indepandants, donc on veux un reseaux neuronnes qui garde l'antecedant pour serve le prochain , ce que RNN peux faire ,et un reseaux neuronnes normal NN va echouer car il oublie l'antecedan.

# %% [markdown]
# ## 2- Inconvénients d’un RNN simple

# %% [markdown]
# #### 1- il ne pas pas appredre des relations complexe de text , car il utilise seulement une seule couche

# %% [markdown]
# #### 2- il a un memoire courte

# %% [markdown]
# #### 3-peut pas generaliser , surtout qu'on a seulement 6 phrases , donc les nouvelles mots comme heureux et triste sont inconnue pour lui

# %% [markdown]
# ## 3-Que se passerait-il si on avait des phrases beaucoup plus longues ?

# %% [markdown]
# #### - notre RNN va connaitre plus de mots

# %% [markdown]
# #### probleme de gradient : notre rnn simple et peux pas apprendre des relations complexes , donc on doit utiliser des extensions comme LSTM ou GRU pour resoudre ca

# %% [markdown]
# #### - on va avoir un entrainement lent , car on va traite plus de sequences

# %% [markdown]
# #### il a perdre de precesion , cause il va trouver un difficulter de compredre le sens global

# %% [markdown]
# #### solution : utlisation de plusieurs couche et des extensions du RNN , avec des robusts etape de pre-traitement de donnees.
