# %% [markdown]
# ## Necessary Libraries Immportation:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import SimpleRNN
from keras.layers import Dropout

# %% [markdown]
# ## Loading Data From CSV File:

# %%
data = pd.read_csv('META.csv')
data.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2018-10-01  163.029999  165.880005  161.259995  162.440002  162.440002
# 1  2018-10-02  161.580002  162.279999  158.669998  159.330002  159.330002
# 2  2018-10-03  160.000000  163.660004  159.529999  162.429993  162.429993
# 3  2018-10-04  161.460007  161.460007  157.350006  158.850006  158.850006
# 4  2018-10-05  159.210007  160.899994  156.199997  157.330002  157.330002
#
#      Volume
# 0  26407700
# 1  36031000
# 2  23109500
# 3  25739600
# 4  25744000

# %% [markdown]
# ## Split train and validation:

# %%
length_data = len(data)
split_ratio = 0.7
length_train = round(length_data * split_ratio)
length_validation = length_data -length_train

# %%
print('length data :',length_data )
print('length train :', length_train)
print('length validation :', length_validation)
# Out:
# length data : 1257
# length train : 880
# length validation : 377

# %%
train_data = data[:length_train].iloc[:,:2]
train_data['Date'] = pd.to_datetime(train_data['Date'])
train_data
# Out:
#           Date        Open
# 0   2018-10-01  163.029999
# 1   2018-10-02  161.580002
# 2   2018-10-03  160.000000
# 3   2018-10-04  161.460007
# 4   2018-10-05  159.210007
# ..         ...         ...
# 875 2022-03-23  213.330002
# 876 2022-03-24  215.000000
# 877 2022-03-25  220.509995
# 878 2022-03-28  222.130005
# 879 2022-03-29  226.070007
#
# [880 rows x 2 columns]

# %%
validation_data = data[length_train:].iloc[:,:2]
validation_data['Date'] = pd.to_datetime(validation_data['Date'])
validation_data
# Out:
#            Date        Open
# 880  2022-03-30  228.910004
# 881  2022-03-31  228.449997
# 882  2022-04-01  224.550003
# 883  2022-04-04  225.979996
# 884  2022-04-05  234.080002
# ...         ...         ...
# 1252 2023-09-22  299.299988
# 1253 2023-09-25  295.640015
# 1254 2023-09-26  297.660004
# 1255 2023-09-27  300.450012
# 1256 2023-09-28  298.940002
#
# [377 rows x 2 columns]

# %%
dataset_train = train_data.Open.values
dataset_train.shape
# Out:
# (880,)

# %%
# reshape
dataset_train = np.reshape(dataset_train,(-1,1))
dataset_train.shape
# Out:
# (880, 1)

# %% [markdown]
# ## Normalize Data:

# %%
scaler = MinMaxScaler(feature_range=(0,1))
dataset_train_scaled = scaler.fit_transform(dataset_train)

# %% [markdown]
# ## Visualize Data:

# %%
plt.subplots(figsize=(15,6))
plt.plot(dataset_train_scaled)
plt.xlabel('days')
plt.ylabel('open price')
# Out:
# Text(0, 0.5, 'open price')

# %%
X_train = []
y_train = []

time_step = 50

for i in range(time_step, length_train):
    # time_step=50, length_train=880, [51-50, 51]
    X_train.append(dataset_train_scaled[i-time_step:i, 0])
    y_train.append(dataset_train_scaled[i, 0])


X_train, y_train = np.array(X_train), np.array(y_train)

# %%
X_train.shape
# Out:
# (830, 50)

# %%
#reshape and expand dimension
X_train = np.reshape(X_train,(X_train.shape[0], X_train.shape[1],1))
y_train = np.reshape(y_train,(y_train.shape[0] ,1))

print(X_train.shape)
print(y_train.shape)
# Out:
# (830, 50, 1)
# (830, 1)

# %% [markdown]
# ## RNN Model Architecture:

# %%
reg =Sequential()
reg.add(SimpleRNN(units=50, activation='tanh', return_sequences=True,input_shape=(X_train.shape[1], 1)))
reg.add(Dropout(0.2))
reg.add(SimpleRNN(units=50, activation='tanh', return_sequences=True))
reg.add(Dropout(0.2))
reg.add(SimpleRNN(units=50, activation='tanh', return_sequences=True))
reg.add(Dropout(0.2))
reg.add(SimpleRNN(units=50))
reg.add(Dropout(0.2))


reg.add(Dense(units=1))
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %% [markdown]
# ## Model Compile with Adam Optimizer:

# %%
reg.compile(optimizer='adam', loss='mean_squared_error', metrics=['accuracy'])
history = reg.fit(X_train, y_train, epochs=100, batch_size=32)
# Out:
# Epoch 1/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 12s 63ms/step - accuracy: 2.8670e-04 - loss: 0.5363
# Epoch 2/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - accuracy: 8.2515e-04 - loss: 0.3077
# Epoch 3/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.0012 - loss: 0.2550
# Epoch 4/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.0023 - loss: 0.1920
# Epoch 5/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - accuracy: 8.4909e-04 - loss: 0.1484
# Epoch 6/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - accuracy: 0.0019 - loss: 0.1480
# Epoch 7/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.0026 - loss: 0.1274
# Epoch 8/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 6.6532e-04 - loss: 0.0980
# Epoch 9/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.0011 - loss: 0.0925
# Epoch 10/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.0057 - loss: 0.0848
# Epoch 11/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 9.6070e-04 - loss: 0.0748
# Epoch 12/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.0012 - loss: 0.0633
# Epoch 13/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.0048 - loss: 0.0577
# Epoch 14/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - accuracy: 0.0019 - loss: 0.0476
# Epoch 15/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - accuracy: 3.7594e-04 - loss: 0.0425
# Epoch 16/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - accuracy: 0.0025 - loss: 0.0416
# Epoch 17/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step - accuracy: 0.0019 - loss: 0.0379
# Epoch 18/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.0018 - loss: 0.0364
# Epoch 19/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - accuracy: 2.3409e-04 - loss: 0.0325
# Epoch 20/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 8.3173e-04 - loss: 0.0271
# Epoch 21/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.0025 - loss: 0.0268
# Epoch 22/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - accuracy: 0.0016 - loss: 0.0257
# Epoch 23/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.0021 - loss: 0.0223
# Epoch 24/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.0010 - loss: 0.0209
# Epoch 25/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - accuracy: 3.7594e-04 - loss: 0.0209
# Epoch 26/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 66ms/step - accuracy: 0.0016 - loss: 0.0181
# Epoch 27/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 66ms/step - accuracy: 6.6044e-04 - loss: 0.0172
# Epoch 28/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - accuracy: 0.0069 - loss: 0.0177
# Epoch 29/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - accuracy: 7.2853e-04 - loss: 0.0176
# Epoch 30/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 0.0027 - loss: 0.0143
# Epoch 31/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - accuracy: 0.0054 - loss: 0.0147
# Epoch 32/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - accuracy: 0.0035 - loss: 0.0132
# Epoch 33/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 0.0022 - loss: 0.0132
# Epoch 34/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.0035 - loss: 0.0120
# Epoch 35/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - accuracy: 0.0010 - loss: 0.0130
# Epoch 36/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 97ms/step - accuracy: 0.0025 - loss: 0.0122
# Epoch 37/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 74ms/step - accuracy: 0.0046 - loss: 0.0123
# Epoch 38/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - accuracy: 0.0031 - loss: 0.0105
# Epoch 39/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step - accuracy: 0.0012 - loss: 0.0102
# Epoch 40/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 99ms/step - accuracy: 4.6818e-04 - loss: 0.0102
# Epoch 41/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - accuracy: 0.0024 - loss: 0.0097
# Epoch 42/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - accuracy: 0.0016 - loss: 0.0100
# Epoch 43/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 99ms/step - accuracy: 3.6963e-04 - loss: 0.0092
# Epoch 44/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - accuracy: 3.1931e-04 - loss: 0.0086
# Epoch 45/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - accuracy: 0.0020 - loss: 0.0090
# Epoch 46/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - accuracy: 0.0021 - loss: 0.0083
# Epoch 47/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - accuracy: 0.0018 - loss: 0.0084
# Epoch 48/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - accuracy: 0.0030 - loss: 0.0071
# Epoch 49/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - accuracy: 0.0011 - loss: 0.0068
# Epoch 50/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - accuracy: 0.0050 - loss: 0.0083
# Epoch 51/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - accuracy: 0.0057 - loss: 0.0081
# Epoch 52/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 0.0036 - loss: 0.0084
# Epoch 53/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.0020 - loss: 0.0072
# Epoch 54/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - accuracy: 0.0059 - loss: 0.0067
# Epoch 55/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 95ms/step - accuracy: 0.0026 - loss: 0.0070
# Epoch 56/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 71ms/step - accuracy: 0.0020 - loss: 0.0060
# Epoch 57/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.0052 - loss: 0.0057
# Epoch 58/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - accuracy: 0.0016 - loss: 0.0069
# Epoch 59/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - accuracy: 0.0013 - loss: 0.0065
# Epoch 60/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - accuracy: 0.0042 - loss: 0.0060
# Epoch 61/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.0019 - loss: 0.0060
# Epoch 62/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - accuracy: 0.0024 - loss: 0.0062
# Epoch 63/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - accuracy: 0.0013 - loss: 0.0051
# Epoch 64/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - accuracy: 7.9937e-04 - loss: 0.0056
# Epoch 65/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.0032 - loss: 0.0054
# Epoch 66/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - accuracy: 0.0044 - loss: 0.0056
# Epoch 67/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.0010 - loss: 0.0053
# Epoch 68/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - accuracy: 0.0013 - loss: 0.0055
# Epoch 69/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step - accuracy: 0.0027 - loss: 0.0044
# Epoch 70/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step - accuracy: 0.0032 - loss: 0.0053
# Epoch 71/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - accuracy: 4.7736e-04 - loss: 0.0050
# Epoch 72/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 80ms/step - accuracy: 0.0023 - loss: 0.0055
# Epoch 73/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - accuracy: 0.0020 - loss: 0.0052
# Epoch 74/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.0026 - loss: 0.0042
# Epoch 75/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - accuracy: 0.0043 - loss: 0.0044
# Epoch 76/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 8.9941e-04 - loss: 0.0047
# Epoch 77/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - accuracy: 0.0037 - loss: 0.0038
# Epoch 78/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - accuracy: 4.8893e-04 - loss: 0.0046
# Epoch 79/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.0017 - loss: 0.0049
# Epoch 80/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - accuracy: 0.0012 - loss: 0.0046
# Epoch 81/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - accuracy: 0.0041 - loss: 0.0041
# Epoch 82/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - accuracy: 0.0020 - loss: 0.0041
# Epoch 83/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - accuracy: 0.0015 - loss: 0.0046
# Epoch 84/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 65ms/step - accuracy: 0.0033 - loss: 0.0050
# Epoch 85/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - accuracy: 0.0029 - loss: 0.0044
# Epoch 86/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - accuracy: 0.0014 - loss: 0.0036
# Epoch 87/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - accuracy: 0.0020 - loss: 0.0042
# Epoch 88/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - accuracy: 0.0020 - loss: 0.0039
# Epoch 89/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - accuracy: 0.0035 - loss: 0.0036
# Epoch 90/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - accuracy: 4.8893e-04 - loss: 0.0037
# Epoch 91/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - accuracy: 0.0046 - loss: 0.0035
# Epoch 92/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.0053 - loss: 0.0039
# Epoch 93/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - accuracy: 0.0018 - loss: 0.0038
# Epoch 94/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.0021 - loss: 0.0035
# Epoch 95/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - accuracy: 0.0049 - loss: 0.0031
# Epoch 96/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - accuracy: 0.0029 - loss: 0.0033
# Epoch 97/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 98ms/step - accuracy: 0.0041 - loss: 0.0037
# Epoch 98/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - accuracy: 0.0060 - loss: 0.0035
# Epoch 99/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - accuracy: 0.0025 - loss: 0.0033
# Epoch 100/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step - accuracy: 0.0015 - loss: 0.0035

# %%
y_pred = reg.predict(X_train)
y_pred = scaler.inverse_transform(y_pred)
# Out:
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 85ms/step

# %%
# plot Y_train and Y_pred
plt.figure(figsize=(30, 10))
plt.plot(y_pred, color='b', label='y predicted')
plt.plot(scaler.inverse_transform(y_train), color = 'g', label = ' y train')

plt.xlabel('Days')
plt.ylabel('Open Price')


plt.legend()

plt.show()

# %% [markdown]
# ## Evaluate model on validation data:

# %%
dataset_validation = validation_data.Open.values
dataset_validation = np.reshape(dataset_validation, (-1, 1))
scaled_dataset_validation = scaler.fit_transform(dataset_validation)
scaled_dataset_validation.shape
# Out:
# (377, 1)

# %%
y_test = []
X_test = []


for i in range(time_step, length_validation):
    X_test.append(scaled_dataset_validation[i-time_step:i, 0])
    y_test.append(scaled_dataset_validation[i, 0])

# %%
X_test, y_test = np.array(X_test), np.array(y_test)

# %%
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
y_test = np.reshape(y_test, (-1, 1))

# %%
y_pred_of_test = reg.predict(X_test)
y_pred_of_test = scaler.inverse_transform(y_pred_of_test)
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step

# %%
plt.figure(figsize=(30, 10))
plt.plot(y_pred_of_test, color='b', label='y predicted')
plt.plot( scaler.inverse_transform(y_test), color = 'g', label = ' y test')

plt.xlabel('Days')
plt.ylabel('Open Price')


plt.legend()

plt.show()
